# %% [markdown]
# <a href="https://colab.research.google.com/github/SafiyyahKazim/Google-COLAB/blob/master/office.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(style='whitegrid', palette='muted', font_scale=1.5)
plt.figsize=(16, 10)
sns.set(rc={"figure.figsize": (16, 10)}); np.random.seed(0)

# %%
office_data = pd.read_csv('/content/OfficeSupplies.csv')

# %%
office_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OrderDate   43 non-null     object
#  1   Region      43 non-null     object
#  2   Rep         43 non-null     object
#  3   Item        43 non-null     object
#  4   Units       43 non-null     int64
#  5   Unit Price  43 non-null     float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 2.1+ KB

# %%
office_data.head(10)
# Out:
#      OrderDate   Region      Rep     Item  Units  Unit Price
# 0   4-Jul-2014     East  Richard  Pen Set     62        4.99
# 1  12-Jul-2014     East     Nick   Binder     29        1.99
# 2  21-Jul-2014  Central   Morgan  Pen Set     55       12.49
# 3  29-Jul-2014     East    Susan   Binder     81       19.99
# 4   7-Aug-2014  Central  Matthew  Pen Set     42       23.95
# 5  15-Aug-2014     East  Richard   Pencil     35        4.99
# 6  24-Aug-2014     West    James     Desk      3      275.00
# 7   1-Sep-2014  Central    Smith     Desk      2      125.00
# 8  10-Sep-2014  Central     Bill   Pencil      7        1.29
# 9  18-Sep-2014     East  Richard  Pen Set     16       15.99

# %%
sns.displot(office_data, x="Item", col="Rep")

# %%
sns.displot(office_data, x="Item", col="Unit Price")

# %%
ax = sns.countplot(x="Unit Price", data=office_data)

# %%
ax = sns.countplot(y="Item", data=office_data)

# %%
sns.histplot(data=office_data, x="Item")

# %%
sns.lineplot(data=office_data, y="OrderDate", x="Units")
plt.xticks(rotation=45, ha='right')
# Out:
# (array([-20.,   0.,  20.,  40.,  60.,  80., 100., 120.]),
#  <a list of 8 Text major ticklabel objects>)
