# %% [markdown]
# <a href="https://colab.research.google.com/github/SafiyyahKazim/Google-COLAB/blob/master/7000rows.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(style='whitegrid', palette='muted', font_scale=1.5)
plt.figsize=(16, 10)

# %%
df = pd.read_csv('/content/test_ListOfOrders.csv')

# %%
df.head()
# Out:
#   Category (OrderBreakdown1)  ... Sales (OrderBreakdown1)
# 0            Office Supplies  ...                      45
# 1                  Furniture  ...                     854
# 2            Office Supplies  ...                     140
# 3            Office Supplies  ...                      27
# 4            Office Supplies  ...                      17
#
# [5 rows x 18 columns]

# %%
sns.displot(df, x="Profit (OrderBreakdown1)", bins=20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8047 entries, 0 to 8046
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Category (OrderBreakdown1)      8047 non-null   object
#  1   City                            8047 non-null   object
#  2   Country                         8047 non-null   object
#  3   Customer Name                   8047 non-null   object
#  4   Order Date                      8047 non-null   object
#  5   Order ID                        8047 non-null   object
#  6   Order ID (OrderBreakdown1)      8047 non-null   object
#  7   Product Name (OrderBreakdown1)  8047 non-null   object
#  8   Region                          8047 non-null   object
#  9   Segment                         8047 non-null   object
#  10  Ship Date                       8047 non-null   object
#  11  Ship Mode                       8047 non-null   object
# ...

# %%
plt.figure(figsize = (16,8))

sns.barplot(data = df, x = 'Sales (OrderBreakdown1)', y = 'Segment').set_title('Total Claims by Regions')
plt.xticks(rotation = 90)
# Out:
# (array([  0.,  50., 100., 150., 200., 250., 300., 350.]),
#  <a list of 8 Text major ticklabel objects>)

# %%
sns.countplot(x='Quantity (OrderBreakdown1)',data=df,hue='Region',palette="tab10")

# %%
sns.histplot(x='Quantity (OrderBreakdown1)',data=df,hue='Region',palette="tab10")
